# %%
import pandas as pd
import numpy as np
import io
import csv
import re
import pickle
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
from labellines import labelLine, labelLines

# %%
def getPlayerStacks(entries):
    res = []

    for entry in entries:
        if 'Player stacks:' in entry:
            res.append(entry)

    return res

def getPlayerNames(stackEntries):
    playerIdtoNames = {}

    for entry in stackEntries:
        cur = 0
        
        while cur < len(entry)

# %%
logFile = r'C:\Users\andre\Documents\GitHub\pokersters-graph-viz\poker_now_log_pglOspqSImcpMhp9jjdTaxgM8.csv'

f = open(logFile, 'r')
entries = f.readlines()
f.close()

# %%
getPlayerStacks(entries)
# Out:
# ['"Player stacks: #1 ""Rick @ NctV0vf9uC"" (18.71) | #2 ""Jack @ 9SB4G8Xzs0"" (9.76) | #4 ""Matt @ QgTA6OD2cP"" (33.17) | #7 ""andy @ jtCtnyHTSX"" (17.86) | #9 ""Zach @ 0d09iha5xa"" (9.93) | #10 ""Emily @ Cv51BSc-hD"" (9.63)",2023-02-10T05:50:33.663Z,167600823366301\n',
#  '"Player stacks: #1 ""Rick @ NctV0vf9uC"" (19.86) | #2 ""Jack @ 9SB4G8Xzs0"" (9.78) | #4 ""Matt @ QgTA6OD2cP"" (33.44) | #7 ""andy @ jtCtnyHTSX"" (17.86) | #9 ""Zach @ 0d09iha5xa"" (8.44) | #10 ""Emily @ Cv51BSc-hD"" (9.68)",2023-02-10T05:49:30.751Z,167600817075101\n',
#  '"Player stacks: #1 ""Rick @ NctV0vf9uC"" (19.31) | #2 ""Jack @ 9SB4G8Xzs0"" (9.83) | #4 ""Matt @ QgTA6OD2cP"" (33.69) | #7 ""andy @ jtCtnyHTSX"" (18.11) | #9 ""Zach @ 0d09iha5xa"" (8.44) | #10 ""Emily @ Cv51BSc-hD"" (9.68)",2023-02-10T05:48:38.156Z,167600811815601\n',
# ...
